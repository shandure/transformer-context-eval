# %% [markdown]
# # 🧵 RoPE-Scaled Evaluation Notebook
#
# This notebook demonstrates how to run the **RoPE-scaled evaluation pipeline**.
# By default, it uses **LongChat-7B-16k**, a model with extended context length.
#
# 👉 You can replace it with any Hugging Face model by editing the `MODEL_NAME` variable.

# %%
# --- Parameters ---
MODEL_NAME = "lmsys/longchat-7b-16k"  # RoPE-scaled model
MAX_INPUT_TOKENS = 16384
NUM_TASKS = 10  # small for demo; increase for full runs

# %%
# Install dependencies (skip if already installed in your environment)
# !pip install -r ../requirements.txt

# %%
# Step 1: Build retrieval dataset
# !python ../scripts/build_retrieval_dataset.py \
  --tokenizer_name $MODEL_NAME \
  --class_type B --num_tasks $NUM_TASKS --num_distractors 20 \
  --out_csv ../data/processed/demo_rope.csv

# %%
# Step 2: Truncate prompts
# !python ../scripts/truncate_prompts.py \
  --in_csv ../data/processed/demo_rope.csv \
  --out_csv ../data/processed/demo_rope_truncated.csv \
  --tokenizer_name $MODEL_NAME \
  --max_input_tokens $MAX_INPUT_TOKENS

# %%
# Step 3: Run evaluation
# !python -m src.run_retrieval_eval \
  --model_name $MODEL_NAME \
  --data_path ../data/processed/demo_rope_truncated.csv \
  --output_path ../results/demo_rope_results.csv \
  --max_tokens 1024 \
  --max_input_tokens $MAX_INPUT_TOKENS

# %% [markdown]
# ## ✅ Results
# Your evaluation results will be saved in:
# ```
# ../results/demo_rope_results.csv
# ```
